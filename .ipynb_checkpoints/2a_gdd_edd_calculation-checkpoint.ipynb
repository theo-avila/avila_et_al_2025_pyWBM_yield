# %% [markdown]
# # Growing degree days & Extreme degree days calculations

# %% [markdown]
# ## Packages

# %%
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import dask
import os

# %% [markdown]
# ## Functions

# %%
def degreeDays(single_day, degree_day_method, kelvin_starting=True):
    '''
    Calculates growing degree days, using a piecewise function, ASSUMING KELVIN STARTING
    
    inputs:
    dataset with tmax & tmin as variables as single_day
    degree_day_method, which is either gdd or edd, 10.0 degrees or 29.0 degrees respectively (in degree celsius)
    outputs:
    growing degree days for dataset
    (Haqiqi et al. 2021; D’Agostino and Schlenker, 2015)
    '''
    single_day = single_day.copy(deep=True)
    
    if kelvin_starting:
        single_day = single_day - 273.15

    if degree_day_method == 'gdd':
        corn_baseline = 10.0
        # caps at 29.0 Degrees for iman 2021 purposes
        single_day['tmax'] = xr.where(single_day.tmax > 29.0, 29.0, single_day.tmax)
        
    elif degree_day_method == 'edd':
        corn_baseline = 29.0
        
    else:
        raise Exception(f'Invalid degree_day_method "{degree_day_method}", please specify either "gdd" or "edd"')
        
    gdd_ds = xr.full_like(single_day.tmax, 0.0)

    # b <= tmin
    b_lower_tmin = (single_day.tmin + single_day.tmax) / 2 - corn_baseline
    gdd_ds = xr.where(single_day.tmin >= corn_baseline, b_lower_tmin, gdd_ds)
    
    # tmin < b <= tmax
    arccos_arg = (2 * corn_baseline - single_day.tmax - single_day.tmin) / (single_day.tmax - single_day.tmin)
    arccos_arg = arccos_arg.clip(min=-1, max=1)
    
    t_bar = np.arccos(arccos_arg)
    tmin_lower_b_lower_tmax = (
        t_bar / np.pi * ((single_day.tmax + single_day.tmin) / 2 - corn_baseline)
        + (single_day.tmax - single_day.tmin) / (2 * np.pi) * np.sin(t_bar)
    )
    
    gdd_ds = xr.where((single_day.tmin < corn_baseline) & (corn_baseline <= single_day.tmax), tmin_lower_b_lower_tmax, gdd_ds)
    
    # tmax < b 
    gdd_ds = xr.where((single_day.tmax < corn_baseline), 0, gdd_ds)
    
    return gdd_ds

def yearlyCalculationSum(year, filein_base_yearly):
    '''
    calculates growing degree days, & extreme degree days from a year & file_path.
    This is for the growing season (April 1 to September 31), per Haqiqi et al. 2020
    
    inputs:
    year
    filein_base_yearly that with daily tmax & tmin values
    outputs:
    yearly summed gdd & edd as nc file, saved @ some location as single year nc file
    
    '''
    # we increase the growing season by 1 month on each side (at least to save the files so no important information is lost
    
    try:
        os.mkdir(f"{filein_base_yearly}/{year}/")
    except Exception:
        pass
        
    start_dt = datetime.datetime(year, 1, 1, 0, 0)
    end_dt = datetime.datetime(year, 12, 31, 0, 0)
    
    while start_dt <= end_dt:
        yyyymmdd = start_dt.strftime("%Y%m%d")
        filein_i = f"{filein_base_yearly}/{year}/NLDAS_FORA0125_H.A{yyyymmdd}.nc"
        
        try:
            dataset_i  = xr.open_dataset(filein_i)
            gdd = degreeDays(dataset_i, 'gdd').drop_vars('time', errors='ignore')
            edd = degreeDays(dataset_i, 'edd').drop_vars('time', errors='ignore')
            
            combined_dataset = xr.Dataset({
            "gdd": gdd,
            "edd": edd
             })
            dataset_i.close()
            combined_dataset.to_netcdf(f"{filein_base_yearly}/{year}/NLDAS_FORA0125_H.A{yyyymmdd}_dday.nc", mode='w')
            
        except Exception:
            raise Exception(f"issue with downloading or accessing underlying files at {filein_i}")
        
        start_dt += datetime.timedelta(days=1)
    
    return

# %%
filein_base_yearly = "/storage/home/cta5244/work/pyWBM_yield_data/NCEPNARR_NLDAS_tmax_tmin"
start_year = 1979
end_year = 2025

# %%
from dask_jobqueue import SLURMCluster

cluster = SLURMCluster(
    # account="pches",
    account="open",
    cores=1,
    memory="1GiB",
    walltime="03:00:00",
)

cluster.scale(jobs=50)
# Out:
# 2025-03-16 18:30:08,967 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <tornado.platform.asyncio.AsyncIOMainLoop object at 0x152bbf08a470>>, <Task finished name='Task-18' coro=<SpecCluster._correct_state_internal() done, defined at /storage/home/cta5244/mambaforge/envs/pyWBM/lib/python3.10/site-packages/distributed/deploy/spec.py:346> exception=RuntimeError("can't start new thread")>)
# Traceback (most recent call last):
#   File "/storage/home/cta5244/mambaforge/envs/pyWBM/lib/python3.10/site-packages/tornado/ioloop.py", line 750, in _run_callback
#     ret = callback()
#   File "/storage/home/cta5244/mambaforge/envs/pyWBM/lib/python3.10/site-packages/tornado/ioloop.py", line 774, in _discard_future_result
#     future.result()
#   File "/storage/home/cta5244/mambaforge/envs/pyWBM/lib/python3.10/site-packages/distributed/deploy/spec.py", line 390, in _correct_state_internal
#     await asyncio.gather(*worker_futs)
#   File "/storage/home/cta5244/mambaforge/envs/pyWBM/lib/python3.10/asyncio/tasks.py", line 650, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/storage/home/cta5244/mambaforge/envs/pyWBM/lib/python3.10/site-packages/distributed/deploy/spec.py", line 74, in _
#     await self.start()
#   File "/storage/home/cta5244/mambaforge/envs/pyWBM/lib/python3.10/site-packages/dask_jobqueue/core.py", line 426, in start
#     out = await self._submit_job(fn)
#   File "/storage/home/cta5244/mambaforge/envs/pyWBM/lib/python3.10/site-packages/dask_jobqueue/core.py", line 409, in _submit_job
#     return await self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/storage/home/cta5244/mambaforge/envs/pyWBM/lib/python3.10/site-packages/dask_jobqueue/core.py", line 503, in _call
#     proc = await create_subproc(
#   File "/storage/home/cta5244/mambaforge/envs/pyWBM/lib/python3.10/asyncio/subprocess.py", line 218, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#   File "/storage/home/cta5244/mambaforge/envs/pyWBM/lib/python3.10/asyncio/base_events.py", line 1681, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#   File "/storage/home/cta5244/mambaforge/envs/pyWBM/lib/python3.10/asyncio/unix_events.py", line 212, in _make_subprocess_transport
#     watcher.add_child_handler(transp.get_pid(),
#   File "/storage/home/cta5244/mambaforge/envs/pyWBM/lib/python3.10/asyncio/unix_events.py", line 1377, in add_child_handler
#     thread.start()
#   File "/storage/home/cta5244/mambaforge/envs/pyWBM/lib/python3.10/threading.py", line 935, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread

# %%
from dask.distributed import Client

client = Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://146.186.150.13:40153' processes=50 threads=50, memory=50.00 GiB>

# %%
results = []
for year in np.arange(start_year, end_year, 1):
    out = dask.delayed(yearlyCalculationSum)(year=year, filein_base_yearly=filein_base_yearly)
    results.append(out)

# %%
results = dask.compute(*results)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 89, in yearlyCalculationSum()
#      88     dataset_i.close()
# ---> 89     combined_dataset.to_netcdf(f"{filein_base_yearly}/{year}/NLDAS_FORA0125_H.A{yyyymmdd}.nc", mode='w')
#      91 except Exception:
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/core/dataset.py:2372, in to_netcdf()
#    2370 from xarray.backends.api import to_netcdf
# -> 2372 return to_netcdf(  # type: ignore[return-value]  # mypy cannot resolve the overloads:(
#    2373     self,
#    2374     path,
#    2375     mode=mode,
#    2376     format=format,
#    2377     group=group,
#    2378     engine=engine,
#    2379     encoding=encoding,
#    2380     unlimited_dims=unlimited_dims,
#    2381     compute=compute,
#    2382     multifile=False,
#    2383     invalid_netcdf=invalid_netcdf,
#    2384     auto_complex=auto_complex,
#    2385 )
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/backends/api.py:1873, in to_netcdf()
#    1870 try:
#    1871     # TODO: allow this work (setting up the file for writing array data)
#    1872     # to be parallelized with dask
# -> 1873     dump_to_store(
#    1874         dataset, store, writer, encoding=encoding, unlimited_dims=unlimited_dims
#    1875     )
#    1876     if autoclose:
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/backends/api.py:1920, in dump_to_store()
#    1918     variables, attrs = encoder(variables, attrs)
# -> 1920 store.store(variables, attrs, check_encoding, writer, unlimited_dims=unlimited_dims)
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/backends/common.py:447, in store()
#     445     writer = ArrayWriter()
# --> 447 variables, attributes = self.encode(variables, attributes)
#     449 self.set_attributes(attributes)
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/backends/common.py:536, in encode()
#     533 def encode(self, variables, attributes):
#     534     # All NetCDF files get CF encoded by default, without this attempting
#     535     # to write times, for example, would fail.
# --> 536     variables, attributes = cf_encoder(variables, attributes)
#     537     variables = {k: self.encode_variable(v) for k, v in variables.items()}
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/conventions.py:829, in cf_encoder()
#     827 _update_bounds_encoding(variables)
# --> 829 new_vars = {k: encode_cf_variable(v, name=k) for k, v in variables.items()}
#     831 # Remove attrs from bounds variables (issue #2921)
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/conventions.py:829, in <dictcomp>()
#     827 _update_bounds_encoding(variables)
# --> 829 new_vars = {k: encode_cf_variable(v, name=k) for k, v in variables.items()}
#     831 # Remove attrs from bounds variables (issue #2921)
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/conventions.py:197, in encode_cf_variable()
#     187 for coder in [
#     188     times.CFDatetimeCoder(),
#     189     times.CFTimedeltaCoder(),
#    (...)
#     195     variables.BooleanCoder(),
#     196 ]:
# --> 197     var = coder.encode(var, name=name)
#     199 # TODO(kmuehlbauer): check if ensure_dtype_not_object can be moved to backends:
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/coding/times.py:982, in encode()
#     980 def encode(self, variable: Variable, name: T_Name = None) -> Variable:
#     981     if np.issubdtype(
# --> 982         variable.data.dtype, np.datetime64
#     983     ) or contains_cftime_datetimes(variable):
#     984         dims, data, attrs, encoding = unpack_for_encoding(variable)
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/core/variable.py:474, in data()
#     473 elif isinstance(self._data, indexing.ExplicitlyIndexed):
# --> 474     return self._data.get_duck_array()
#     475 else:
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/core/indexing.py:840, in get_duck_array()
#     839 def get_duck_array(self):
# --> 840     self._ensure_cached()
#     841     return self.array.get_duck_array()
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/core/indexing.py:837, in _ensure_cached()
#     836 def _ensure_cached(self):
# --> 837     self.array = as_indexable(self.array.get_duck_array())
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/core/indexing.py:794, in get_duck_array()
#     793 def get_duck_array(self):
# --> 794     return self.array.get_duck_array()
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/core/indexing.py:657, in get_duck_array()
#     654 else:
#     655     # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     656     # it may wrap a BackendArray so use its __getitem__
# --> 657     array = self.array[self.key]
#     659 # self.array[self.key] is now a numpy array when
#     660 # self.array is a BackendArray subclass
#     661 # and self.key is BasicIndexer((slice(None, None, None),))
#     662 # so we need the explicit check for ExplicitlyIndexed
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:103, in __getitem__()
#     102 def __getitem__(self, key):
# --> 103     return indexing.explicit_indexing_adapter(
#     104         key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     105     )
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/core/indexing.py:1018, in explicit_indexing_adapter()
#    1017 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1018 result = raw_indexing_method(raw_key.tuple)
#    1019 if numpy_indices.tuple:
#    1020     # index the loaded np.ndarray
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:115, in _getitem()
#     114 with self.datastore.lock:
# --> 115     original_array = self.get_array(needs_lock=False)
#     116     array = getitem(original_array, key)
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:95, in get_array()
#      94 ds = self.datastore._acquire(needs_lock)
# ---> 95 variable = ds.variables[self.variable_name]
#      96 variable.set_auto_maskandscale(False)
#
# KeyError: 'tmax'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 results = dask.compute(*results)
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/dask/base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# Cell In[11], line 92, in yearlyCalculationSum()
#      89         combined_dataset.to_netcdf(f"{filein_base_yearly}/{year}/NLDAS_FORA0125_H.A{yyyymmdd}.nc", mode='w')
#      91     except Exception:
# ---> 92         raise Exception(f"issue with downloading or accessing underlying files at {filein_i}")
#      94     start_dt += datetime.timedelta(days=1)
#      96 return
#
# Exception: issue with downloading or accessing underlying files at /storage/home/cta5244/work/pyWBM_yield_data/NCEPNARR_NLDAS_tmax_tmin/2009/NLDAS_FORA0125_H.A20090101.nc
