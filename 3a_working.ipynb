# %% [markdown]
# # Binned Calculations?

# %% [markdown]
# ## Packages

# %%
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import dask
import os

# %% [markdown]
# ## Functions

# %%
def something():
    '''
    inputs:
    outputs:
    '''

# %% [markdown]
# ## Calculations

# %%
gdd_filepath = "/storage/home/cta5244/work/pyWBM_yield_data/NCEPNARR_NLDAS_tmax_tmin/2004/NLDAS_FORA0125_H.A20040108.nc"
edd_filepath = gdd_filepath
filein_mosaic = "/storage/group/pches/default/public/NLDAS/MOSAIC/daily/NLDAS_MOS0125_H.A20040108.nc"
filein_vic = "/storage/group/pches/default/public/NLDAS/VIC/daily/NLDAS_VIC0125_H.A20040108.nc"
filein_noah = "/storage/group/pches/default/public/NLDAS/NOAH/daily/NLDAS_NOAH0125_H.A20180108.nc"
xr.open_dataset(filein_noah)
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:       (time: 1, depth: 6, bnds: 2, depth_2: 1, depth_3: 2,
#                    lat: 224, lon: 464)
# Coordinates:
#   * lon           (lon) float64 4kB -124.9 -124.8 -124.7 ... -67.19 -67.06
#   * lat           (lat) float64 2kB 25.06 25.19 25.31 ... 52.69 52.81 52.94
#   * depth         (depth) float64 48B 100.0 50.0 5.0 25.0 70.0 150.0
#   * depth_2       (depth_2) float64 8B 50.0
#   * depth_3       (depth_3) float64 16B 100.0 50.0
#   * time          (time) datetime64[ns] 8B 2018-01-08
# Dimensions without coordinates: bnds
# Data variables:
#     depth_bnds    (time, depth, bnds) float64 96B ...
#     depth_2_bnds  (time, depth_2, bnds) float64 16B ...
#     depth_3_bnds  (time, depth_3, bnds) float64 32B ...
#     SOILM         (time, depth, lat, lon) float32 2MB ...
#     RZSM          (time, depth_2, lat, lon) float32 416kB ...
#     MSTAV         (time, depth_3, lat, lon) float32 831kB ...
# Attributes:
# ...

# %%
NLDAS_0_100_soilm_MOS0125_H.A20240103.020

# %%
filein_mosaic_hr = "/storage/group/pches/default/public/NLDAS/MOS/hourly/NLDAS_MOS0125_H.A20240103.2000.020.nc"
xr.open_dataset(filein_mosaic_hr)['SoilM_0_100cm'].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/mambaforge/envs/pyWBM/lib/python3.10/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/storage/group/pches/default/public/NLDAS/MOS/hourly/NLDAS_MOS0125_H.A20240103.2000.020.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'a426deb2-3b0c-4a7d-9789-bf15a2207ac4']
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
filein_forcing_nldas = "/storage/home/cta5244/work/pyWBM_yield_data/MOS_daily/NLDAS_0_100_soilm_MOS0125_H.A19790109.020.nc"
xr.open_dataset(filein_forcing_nldas)['SoilM_0_100cm'].plot()

# %%
filein_forcing_nldas = "/storage/home/cta5244/work/pyWBM_yield_data/MOS_daily/NLDAS_0_100_soilm_MOS0125_H.A19800101.020.nc"
xr.open_dataset(filein_forcing_nldas)['SoilM_0_100cm'].plot()

# %%
filein_mosaic = "/storage/group/pches/default/public/NLDAS/NOAH/hourly/NLDAS_NOAH0125_H.A19890202.1000.020.nc"
xr.open_dataset(filein_mosaic)
# Out:
# <xarray.Dataset> Size: 22MB
# Dimensions:          (lon: 464, lat: 224, time: 1, bnds: 2)
# Coordinates:
#   * lon              (lon) float32 2kB -124.9 -124.8 -124.7 ... -67.19 -67.06
#   * lat              (lat) float32 896B 25.06 25.19 25.31 ... 52.69 52.81 52.94
#   * time             (time) datetime64[ns] 8B 1989-02-02T10:00:00
# Dimensions without coordinates: bnds
# Data variables: (12/54)
#     time_bnds        (time, bnds) datetime64[ns] 16B ...
#     SWdown           (time, lat, lon) float32 416kB ...
#     LWdown           (time, lat, lon) float32 416kB ...
#     SWnet            (time, lat, lon) float32 416kB ...
#     LWnet            (time, lat, lon) float32 416kB ...
#     Qle              (time, lat, lon) float32 416kB ...
#     ...               ...
#     RCSOL            (time, lat, lon) float32 416kB ...
#     RSmin            (time, lat, lon) float32 416kB ...
#     RSMacr           (time, lat, lon) float32 416kB ...
# ...
