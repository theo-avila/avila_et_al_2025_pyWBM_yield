# %% [markdown]
# # Growing degree days calculations

# %% [markdown]
# ## Packages

# %%
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import dask
import os

# %% [markdown]
# ## Functions

# %% [markdown]
# ## Calculations

# %%
filein_hourly_force = "/storage/group/pches/default/public/NLDAS/forcing/hourly/NLDAS_FORA0125_H.A20200312.1800.002.grb.SUB.nc4"
xr.open_dataset(filein_hourly_force)
# Out:
# <xarray.Dataset> Size: 837kB
# Dimensions:  (time: 1, lon: 464, lat: 224, height: 1)
# Coordinates:
#   * time     (time) datetime64[ns] 8B 2020-03-12T18:00:00
#   * lon      (lon) float64 4kB -124.9 -124.8 -124.7 ... -67.31 -67.19 -67.06
#   * lat      (lat) float64 2kB 25.06 25.19 25.31 25.44 ... 52.69 52.81 52.94
#   * height   (height) float64 8B 2.0
# Data variables:
#     TMP      (time, height, lat, lon) float32 416kB ...
#     APCP     (time, lat, lon) float32 416kB ...
# Attributes:
#     CDI:            Climate Data Interface version 1.9.8 (https://mpimet.mpg....
#     Conventions:    CF-1.6
#     history_L34RS:  'Created by L34RS v1.4.3 @ NASA GES DISC on November 10 2...
#     CDO:            Climate Data Operators version 1.9.8 (https://mpimet.mpg....

# %%
filein_forcing_nldas = "/storage/group/pches/default/public/NLDAS/forcing/daily/NLDAS_FORA0125_H.A20190614.nc"
xr.open_dataset(filein_forcing_nldas)
# Out:
# <xarray.Dataset> Size: 837kB
# Dimensions:  (lon: 464, lat: 224, time: 1)
# Coordinates:
#   * lon      (lon) float64 4kB -124.9 -124.8 -124.7 ... -67.31 -67.19 -67.06
#   * lat      (lat) float64 2kB 25.06 25.19 25.31 25.44 ... 52.69 52.81 52.94
#   * time     (time) datetime64[ns] 8B 2019-06-14
# Data variables:
#     APCP     (time, lat, lon) float32 416kB ...
#     TMP      (time, lat, lon) float32 416kB ...

# %%
filein_mosaic = "/storage/group/pches/default/public/NLDAS/MOSAIC/daily/NLDAS_MOS0125_H.A20190606.nc"
xr.open_dataset(filein_mosaic)
# Out:
# <xarray.Dataset> Size: 3MB
# Dimensions:       (time: 1, depth: 6, bnds: 2, depth_2: 2, lat: 224, lon: 464)
# Coordinates:
#   * lon           (lon) float64 4kB -124.9 -124.8 -124.7 ... -67.19 -67.06
#   * lat           (lat) float64 2kB 25.06 25.19 25.31 ... 52.69 52.81 52.94
#   * depth         (depth) float64 48B 5.0 50.0 100.0 20.0 25.0 120.0
#   * depth_2       (depth_2) float64 16B 100.0 20.0
#   * time          (time) datetime64[ns] 8B 2019-06-06
# Dimensions without coordinates: bnds
# Data variables:
#     depth_bnds    (time, depth, bnds) float64 96B ...
#     depth_2_bnds  (time, depth_2, bnds) float64 32B ...
#     SOILM         (time, depth, lat, lon) float32 2MB ...
#     MSTAV         (time, depth_2, lat, lon) float32 831kB ...
# Attributes:
#     CDI:            Climate Data Interface version 1.9.8 (https://mpimet.mpg....
#     Conventions:    CF-1.6
#     history_L34RS:  'Created by L34RS v1.4.3 @ NASA GES DISC on November 24 2...
# ...
